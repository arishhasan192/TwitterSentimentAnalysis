# %%
import numpy as np
import pandas as pd
data=pd.read_csv('train.csv')
data=np.array(data)
data
# Out:
# array([[567900433542488064, 'negative', 'Southwest', ...,
#         '2015-02-17 20:16:29 -0800', 'Washington D.C.',
#         'Atlantic Time (Canada)'],
#        [569989168903819264, 'positive', 'Southwest', ...,
#         '2015-02-23 14:36:22 -0800', 'Indianapolis, Indiana; USA',
#         'Central Time (US & Canada)'],
#        [568089179520954368, 'positive', 'United', ...,
#         '2015-02-18 08:46:29 -0800', 'Illinois',
#         'Central Time (US & Canada)'],
#        ...,
#        [569643648910028801, 'negative', 'US Airways', ...,
#         '2015-02-22 15:43:24 -0800', 'St. Augustine, Florida', nan],
#        [568864981917110272, 'negative', 'US Airways', ...,
#         '2015-02-20 12:09:15 -0800', nan, nan],
#        [568929299350179840, 'negative', 'United', ...,
#         '2015-02-20 16:24:49 -0800', nan, nan]], dtype=object)

# %%
df=pd.read_csv('train.csv')
df
# Out:
#                  tweet_id airline_sentiment     airline  \
# 0      567900433542488064          negative   Southwest
# 1      569989168903819264          positive   Southwest
# 2      568089179520954368          positive      United
# 3      568928195581513728          negative   Southwest
# 4      568594180014014464          negative      United
# ...                   ...               ...         ...
# 10975  569934458364813313           neutral    American
# 10976  568564006329434113          positive      United
# 10977  569643648910028801          negative  US Airways
# 10978  568864981917110272          negative  US Airways
# 10979  568929299350179840          negative      United
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN  ColeyGirouard                 NaN
# 1                        NaN  WalterFaddoul                 NaN
# 2                        NaN      LocalKyle                 NaN
# ...

# %%
df3=pd.read_csv('test.csv')
df4=df3.drop(['tweet_coord','airline_sentiment_gold','negativereason_gold','tweet_created','tweet_id'],axis=1)
df4=df3[['airline','text']]
data_test=np.array(df4)
data_test.shape
# Out:
# (3660, 2)

# %%
df2=df.drop(['tweet_coord','airline_sentiment_gold','negativereason_gold','tweet_created','tweet_id'],axis=1)
df2=df[['airline','text','airline_sentiment']]
data=np.array(df2)
data.shape
# Out:
# (10980, 3)

# %%
type(data[0][0])
# Out:
# str

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
words=[]
for i in range(len(data)):
    temp=[]
    for j in range(len(data[i])-1):
        if j==1:
            temp=temp+(word_tokenize(data[i][j]))
        else:
            temp.append(data[i][j])
    words.append([temp,data[i][2]])
words
# Out:
# [[['Southwest',
#    '@',
#    'SouthwestAir',
#    'I',
#    'am',
#    'scheduled',
#    'for',
#    'the',
#    'morning',
#    ',',
#    '2',
#    'days',
#    'after',
#    'the',
#    'fact',
#    ',',
#    'yes',
#    '..',
#    'not',
#    'sure',
#    'why',
#    'my',
#    'evening',
#    'flight',
#    'was',
#    'the',
#    'only',
#    'one',
#    'Cancelled',
#    'Flightled'],
#   'negative'],
#  [['Southwest',
#    '@',
#    'SouthwestAir',
#    'seeing',
#    'your',
#    'workers',
#    'time',
#    'in',
#    'and',
#    'time',
#    'out',
#    'going',
#    'above',
#    'and',
#    'beyond',
#    'is',
#    'why',
#    'I',
#    'love',
#    'flying',
#    'with',
#    'you',
#    'guys',
#    '.',
#    'Thank',
#    'you',
#    '!'],
#   'positive'],
#  [['United',
#    '@',
#    'united',
#    'Flew',
#    'ORD',
#    'to',
#    'Miami',
#    'and',
#    'back',
#    'and',
#    'had',
#    'great',
#    'crew',
#    ',',
#    'service',
#    'on',
# ...

# %%
words_test=[]
for i in range(len(data_test)):
    temp=[]
    for j in range(len(data_test[i])):
        if j==1:
            temp=temp+(word_tokenize(data_test[i][j]))
        else:
            temp.append(data_test[i][j])
    words_test.append(temp)
words_test
# Out:
# [['American',
#   '@',
#   'AmericanAir',
#   'In',
#   'car',
#   'gng',
#   'to',
#   'DFW',
#   '.',
#   'Pulled',
#   'over',
#   '1hr',
#   'ago',
#   '-',
#   'very',
#   'icy',
#   'roads',
#   '.',
#   'On-hold',
#   'with',
#   'AA',
#   'since',
#   '1hr',
#   '.',
#   'Ca',
#   "n't",
#   'reach',
#   'arpt',
#   'for',
#   'AA2450',
#   '.',
#   'Wat',
#   '2',
#   'do',
#   '?'],
#  ['American',
#   '@',
#   'AmericanAir',
#   'after',
#   'all',
#   ',',
#   'the',
#   'plane',
#   'didn',
#   '’',
#   't',
#   'land',
#   'in',
#   'identical',
#   'or',
#   'worse',
#   ')',
#   'conditions',
#   'at',
#   'GRK',
#   'according',
#   'to',
#   'METARs',
#   '.'],
#  ['Southwest',
#   '@',
#   'SouthwestAir',
#   'ca',
#   "n't",
#   'believe',
#   'how',
#   'many',
#   'paying',
#   'customers',
#   'you',
#   'left',
#   'high',
#   'and',
#   'dry',
#   'with',
#   'no',
#   'reason',
#   'for',
#   'flight',
#   'Cancelled',
#   'Flightlations',
#   'Monday',
# ...

# %%
from nltk.corpus import stopwords
import string
stops=stopwords.words('english')+list(string.punctuation)
stops
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag): #creating simple tags to pass into the lemmatizer
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
from nltk import pos_tag

# %%
def clean_review(words):
    output_words=[]
    for w in words:
        if w not in stops and type(w)!=float:
            pos=pos_tag([w])
            clean_word=lemmatizer.lemmatize(w,get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words

# %%
documents = [(clean_review(word), category) for word, category in words]

# %%
documents_testing = [(clean_review(word)) for word in words_test]

# %%
documents_testing[0]
# Out:
# ['american',
#  'americanair',
#  'in',
#  'car',
#  'gng',
#  'dfw',
#  'pulled',
#  '1hr',
#  'ago',
#  'icy',
#  'road',
#  'on-hold',
#  'aa',
#  'since',
#  '1hr',
#  'ca',
#  "n't",
#  'reach',
#  'arpt',
#  'aa2450',
#  'wat',
#  '2']

# %%
documents[0]
# Out:
# (['southwest',
#   'southwestair',
#   'i',
#   'schedule',
#   'morning',
#   '2',
#   'day',
#   'fact',
#   'yes',
#   '..',
#   'sure',
#   'even',
#   'flight',
#   'one',
#   'cancelled',
#   'flightled'],
#  'negative')

# %%
all_words = []
for doc in documents:
    all_words += doc[0]

# %%
freq = nltk.FreqDist(all_words)                 #will retrurn a freq distribution object
common = freq.most_common(3000)
features = [i[0] for i in common] #choosing the top 3000 frequency words

# %%
def get_feature_dict(words): #will return true/false if the word in present in the document or not
    current_features = {}
    words_set = set(words)
    for w in features:
        current_features[w] = w in words_set
    return current_features

# %%
training_data = [(get_feature_dict(doc), category) for doc, category in documents]

# %%
testing_data=[(get_feature_dict(doc),'') for doc in documents_testing]

# %%
testing_data[0]
# Out:
# ({'united': False,
#   'i': False,
#   'flight': False,
#   'usairways': False,
#   'americanair': True,
#   'us airways': False,
#   'american': True,
#   'southwest': False,
#   'southwestair': False,
#   'jetblue': False,
#   'delta': False,
#   'get': False,
#   "n't": True,
#   "'s": False,
#   'http': False,
#   'hour': False,
#   'thanks': False,
#   'cancelled': False,
#   'service': False,
#   'help': False,
#   'customer': False,
#   'time': False,
#   '...': False,
#   'u': False,
#   'call': False,
#   'bag': False,
#   'plane': False,
#   'wait': False,
#   'go': False,
#   'amp': False,
#   'need': False,
#   'hold': False,
#   'fly': False,
#   "'m": False,
#   'make': False,
#   '2': True,
#   'thank': False,
#   'would': False,
#   'still': False,
#   'one': False,
#   'gate': False,
#   'day': False,
#   'please': False,
#   'back': False,
#   'ca': True,
#   'delayed': False,
#   'try': False,
#   'airline': False,
#   'take': False,
#   'virginamerica': False,
# ...

# %%
training_data[0]
# Out:
# ({'united': False,
#   'i': True,
#   'flight': True,
#   'usairways': False,
#   'americanair': False,
#   'us airways': False,
#   'american': False,
#   'southwest': True,
#   'southwestair': True,
#   'jetblue': False,
#   'delta': False,
#   'get': False,
#   "n't": False,
#   "'s": False,
#   'http': False,
#   'hour': False,
#   'thanks': False,
#   'cancelled': True,
#   'service': False,
#   'help': False,
#   'customer': False,
#   'time': False,
#   '...': False,
#   'u': False,
#   'call': False,
#   'bag': False,
#   'plane': False,
#   'wait': False,
#   'go': False,
#   'amp': False,
#   'need': False,
#   'hold': False,
#   'fly': False,
#   "'m": False,
#   'make': False,
#   '2': True,
#   'thank': False,
#   'would': False,
#   'still': False,
#   'one': True,
#   'gate': False,
#   'day': True,
#   'please': False,
#   'back': False,
#   'ca': False,
#   'delayed': False,
#   'try': False,
#   'airline': False,
#   'take': False,
#   'virginamerica': False,
# ...

# %%
from nltk import NaiveBayesClassifier 
classifier = NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(classifier, training_data)
# Out:
# 0.836976320582878

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                    kudos = True           positi : negati =     51.9 : 1.0
#                fantastic = True           positi : negati =     34.2 : 1.0
#                 favorite = True           positi : negati =     34.2 : 1.0
#              outstanding = True           positi : negati =     29.1 : 1.0
#                  helpful = True           positi : neutra =     26.3 : 1.0
#                    flyfi = True           positi : negati =     24.1 : 1.0
#                    thank = True           positi : negati =     22.6 : 1.0
#                  awesome = True           positi : negati =     22.6 : 1.0
#                     hold = True           negati : positi =     22.3 : 1.0
#                beautiful = True           positi : negati =     21.5 : 1.0
#                       hr = True           negati : positi =     21.4 : 1.0
#                    daily = True           neutra : negati =     20.6 : 1.0
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
categories=[category for document,category in documents]

# %%
categories
# Out:
# ['negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'neutral',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'neutral',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'positive',
#  'positive',
#  'negative',
#  'neutral',
#  'neutral',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'neutral',
#  'negative',
#  'neutral',
# ...

# %%
train_documents=[" ".join(document) for document,category in documents]

# %%
test_documents=[" ".join(document) for document in documents_testing]

# %%
test_documents
# Out:
# ["american americanair in car gng dfw pulled 1hr ago icy road on-hold aa since 1hr ca n't reach arpt aa2450 wat 2",
#  'american americanair plane ’ land identical bad condition grk accord metars',
#  "southwest southwestair ca n't believe many pay customer left high dry reason flight cancelled flightlations monday bdl wow",
#  'us airways usairways i legitimately say i would rather driven cross country flown us airways',
#  'american americanair still response aa great job guy',
#  'united united developer fly tmrw morn w/45 min layover earlier flight 1.5hr layover move',
#  'us airways usairways hello anyone',
#  'us airways usairways husainhaqqani mr. husain u shld protest well one ur party member rehman malik delayed pia flight hour ..',
#  "us airways usairways likely flightaware say plane still durango n't depart",
#  "american americanair n't even give option hold .. just say line busy plz try late flightr",
# ...

# %%
count_vec=CountVectorizer(max_features=3000)
x_train_features=count_vec.fit_transform(train_documents)

# %%
count_vec.get_feature_names()
# Out:
# ['00',
#  '000',
#  '00pm',
#  '02',
#  '03',
#  '05',
#  '05pm',
#  '10',
#  '100',
#  '1000',
#  '10pm',
#  '11',
#  '11th',
#  '12',
#  '1230',
#  '13',
#  '130',
#  '14',
#  '140',
#  '15',
#  '150',
#  '152',
#  '1583',
#  '15th',
#  '16',
#  '17',
#  '18',
#  '180',
#  '1800',
#  '1898',
#  '19',
#  '1hr',
#  '1k',
#  '1pm',
#  '1st',
#  '20',
#  '200',
#  '2000',
#  '2012',
#  '2014',
#  '2015',
#  '20min',
#  '21',
#  '21st',
#  '22',
#  '23',
#  '24',
#  '24h',
#  '24hrs',
#  '24th',
#  '25',
#  '250',
#  '26',
#  '27',
#  '28',
#  '28th',
#  '29',
#  '2b',
#  '2d',
#  '2day',
#  '2days',
#  '2hr',
#  '2hrs',
#  '2nd',
#  '2pm',
#  '2x',
#  '30',
#  '300',
#  '3056',
#  '30a',
#  '30am',
#  '30min',
#  '30pm',
#  '31',
#  '3130',
#  '32',
#  '35',
#  '36',
#  '386',
#  '39',
#  '3am',
#  '3d',
#  '3hrs',
#  '3pm',
#  '3rd',
#  '3x',
#  '40',
#  '400',
#  '403',
#  '404',
#  '40pm',
#  '413',
#  '42',
#  '4322',
#  '433',
#  '44',
#  '45',
#  '4567',
#  '45min',
#  '47',
# ...

# %%
x_test_features=count_vec.transform(test_documents)

# %%
x_test_features
# Out:
# <3660x3000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 38166 stored elements in Compressed Sparse Row format>

# %%
from sklearn.svm import SVC

# %%
svc=SVC()
svc.fit(x_train_features,categories)
# Out:
# SVC()

# %%
result=svc.predict(x_test_features)
# Out:
# array(['negative', 'negative', 'negative', ..., 'neutral', 'positive',
#        'negative'], dtype='<U8')

# %%
import numpy as np
np.savetxt('output.csv',result,delimiter=',',fmt='%s')
